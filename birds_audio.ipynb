# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannynis/Acoustic-Scene-Classification-and-Time-of-Day-Estimation/blob/main/birds_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

files = [str(x) for x in Path(r'/content/drive/MyDrive/birds_project/bird identification2/').rglob('*.WAV')]

# %%
files[1000]
# Out:
# '/content/drive/MyDrive/birds_project/bird identification2/Quarantine recordings Tel Aviv (Yoel)/spot 11/Device 4/21-30.05.2020/20200521_062200.WAV'

# %%
import librosa

# %%
w,sr = librosa.load(files[1000],sr=44100)

# %%
import IPython

# %%
IPython.display.Audio(w,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Data explore

# %%
import torch
import librosa
import soundfile as sf
import skimage.measure
import numpy as np
